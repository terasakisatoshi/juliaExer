# %% [markdown]
# #  Use Python from Julia Notebook

# %%
using PyPlot

# %%
xs=linspace(-π,π,100)
ys=sin.(xs)
plot(xs,ys)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x126dc1a10>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x126e39f10>

# %%
using PyCall

# %%
@pyimport numpy as np
@pyimport matplotlib.pyplot as pyplot
xs=np.linspace(-np.pi,np.pi,100)
ys=np.sin(xs)
pyplot.plot(xs,ys)
pyplot.show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x12ffb5ed0>)

# %%
@pyimport glob
files=glob.glob("*")
for f in files
    println(f)
end
# Out:
# use julia from Python notebook.ipynb
# use Python from Julia notebook.ipynb
