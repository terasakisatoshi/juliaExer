# %%
versioninfo()
# Out:
# Julia Version 0.7.0
# Commit a4cb80f3ed (2018-08-08 06:46 UTC)
# Platform Info:
#   OS: macOS (x86_64-apple-darwin14.5.0)
#   CPU: Intel(R) Core(TM) M-5Y51 CPU @ 1.10GHz
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-6.0.0 (ORCJIT, broadwell)

# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
N=200
d = 8π/N
xs=[d*n*cos(d*n) for n in 0:N]
ys=[d*n*sin(d*n) for n in 0:N]
zs = 0.0:N
plot(xs,ys,zs,marker=:circle)
